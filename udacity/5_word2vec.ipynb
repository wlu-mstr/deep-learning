# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# 5575192
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-f350a1c976ab> in <module>()
#      14   return filename
#      15
# ---> 16 filename = maybe_download('text8.zip', 31344016)
#
# <ipython-input-2-f350a1c976ab> in maybe_download(filename, expected_bytes)
#      11     print(statinfo.st_size)
#      12     raise Exception(
# ---> 13       'Failed to verify ' + filename + '. Can you get to it with a browser?')
#      14   return filename
#      15
#
# Exception: Failed to verify text8.zip. Can you get to it with a browser?

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-3-214d650abd0e> in <module>()
#       5   return data
#       6
# ----> 7 words = read_data('text8')
#       8 print('Data size %d' % len(words))
#
# <ipython-input-3-214d650abd0e> in read_data(filename)
#       1 def read_data(filename):
#       2   """Extract the first file enclosed in a zip file as a list of words"""
# ----> 3   with zipfile.ZipFile(filename) as f:
#       4     data = tf.compat.as_str(f.read(f.namelist()[0])).split()
#       5   return data
#
# /anaconda3/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1106         try:
#    1107             if mode == 'r':
# -> 1108                 self._RealGetContents()
#    1109             elif mode in ('w', 'x'):
#    1110                 # set the modified flag so central directory gets written
#
# /anaconda3/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1173             raise BadZipFile("File is not a zip file")
#    1174         if not endrec:
# -> 1175             raise BadZipFile("File is not a zip file")
#    1176         if self.debug > 1:
#    1177             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
words = None
with open('text8') as f:
    words = tf.compat.as_str(f.read()).split()

# %%
#17005207
len(words)
# Out:
# 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.shape)
  print(train_labels.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 128)
# (128, 1)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.797662
# Nearest to about: tallinn, brevity, karaca, spr, reuter, separates, dukkha, strictest,
# Nearest to three: first, shaughnessy, retellings, kerosene, ipswich, seperate, herons, pressure,
# Nearest to at: steps, monopolistic, zeno, jr, scranton, disguising, intentional, cccc,
# Nearest to on: renovate, dan, rhymed, markers, decry, moulds, texts, leonel,
# Nearest to and: holt, weierstrass, coloured, oedipus, erroneous, eruption, donaghy, mvs,
# Nearest to is: uncivilized, afrika, isolated, vernon, rotated, illusion, informatique, syndromes,
# Nearest to but: relocated, telling, network, accommodation, clarkson, drops, tecumseh, workload,
# Nearest to his: taito, pygmy, sit, nearing, severely, keller, hymen, hairless,
# Nearest to often: derogatory, amenities, pelagianism, ayyubid, pearls, intersects, nuclei, viewpoint,
# Nearest to state: boast, nia, songwriting, plenum, kamikaze, acm, leaping, stoner,
# Nearest to i: confucius, treatment, libyans, yugoslav, rocket, independents, revision, counterculture,
# Nearest to called: guesses, weasel, disrupting, digby, relativism, airplane, vy, polly,
# Nearest to they: tuva, monody, montgomery, wealthy, recognised, visibility, isadora, activating,
# Nearest to there: belshazzar, cork, beuve, dative, scandinavian, aeneid, policemen, ana,
# Nearest to was: hepatic, disavow, knute, vans, funerary, leclerc, wheatstone, weill,
# Nearest to by: fallacious, pitted, cathedral, dorpat, hutch, decommissioned, transcendentalist, kosovar,
# Average loss at step 2000: 4.375211
# Average loss at step 4000: 3.870818
# Average loss at step 6000: 3.791099
# Average loss at step 8000: 3.686656
# Average loss at step 10000: 3.611500
# Nearest to about: spr, tallinn, karaca, fineness, predestined, wet, lmi, rocketry,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to at: from, in, of, suns, premium, effigy, distant, fascinating,
# Nearest to on: in, ipx, with, abstracted, splintered, dan, texts, text,
# Nearest to and: or, s, abodes, of, american, who, but, ly,
# Nearest to is: was, are, has, be, but, naomi, goldstein, ajanta,
# Nearest to but: airplay, couper, are, lillian, is, telling, and, pentagram,
# Nearest to his: their, its, the, s, taito, fealty, nearing, her,
# Nearest to often: also, punished, now, still, synaptic, lodges, derogatory, maclennan,
# Nearest to state: boast, nia, songwriting, acm, tilde, capital, refugees, leaping,
# Nearest to i: libyans, nevertheless, henchmen, justifying, necessitated, pkn, unlimited, complexes,
# Nearest to called: guesses, mut, weasel, pickard, agadir, impractical, shortfalls, airplane,
# Nearest to they: he, there, it, not, we, tuva, she, activating,
# Nearest to there: it, they, he, representative, also, usually, now, whimsical,
# Nearest to was: is, had, were, americana, by, has, wheatstone, are,
# Nearest to by: was, be, southwark, fallacious, golfo, finite, talons, wheatstone,
# Average loss at step 12000: 3.605572
# Average loss at step 14000: 3.573270
# Average loss at step 16000: 3.407341
# Average loss at step 18000: 3.449725
# Average loss at step 20000: 3.541463
# Nearest to about: spr, tallinn, karaca, criminality, organisational, squalor, unreleased, predestined,
# Nearest to three: four, seven, five, two, six, eight, zero, nine,
# Nearest to at: in, from, fascinating, basics, dunsany, gradual, with, clicks,
# Nearest to on: in, ipx, splintered, peas, upon, into, dan, at,
# Nearest to and: or, but, in, televised, melee, external, for, d,
# Nearest to is: was, has, are, be, does, were, but, fashioned,
# Nearest to but: however, and, was, which, that, though, although, apollinaire,
# Nearest to his: their, its, her, fealty, the, this, beckenbauer, commanders,
# Nearest to often: also, still, now, sometimes, punished, usually, synaptic, there,
# Nearest to state: capital, nia, acm, sulfate, plenum, refugees, tilde, boast,
# Nearest to i: consubstantiation, libyans, motivating, ii, sindh, bursts, they, revolutions,
# Nearest to called: mut, agadir, guesses, cooled, pickard, alive, impractical, mace,
# Nearest to they: there, he, we, it, she, not, who, you,
# Nearest to there: it, they, he, usually, now, generally, which, who,
# Nearest to was: is, had, has, were, does, but, be, became,
# Nearest to by: be, adopters, in, with, was, southwark, godhead, childs,
# Average loss at step 22000: 3.499173
# Average loss at step 24000: 3.486180
# Average loss at step 26000: 3.486451
# Average loss at step 28000: 3.479566
# Average loss at step 30000: 3.506248
# Nearest to about: spr, clav, koestler, unreleased, karaca, ironically, influenza, considered,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to at: in, over, during, steps, under, between, on, clicks,
# Nearest to on: in, upon, peas, at, caesium, during, around, bok,
# Nearest to and: or, but, in, however, among, from, against, contaminants,
# Nearest to is: was, has, are, does, but, became, be, extremism,
# Nearest to but: however, though, although, while, and, that, is, did,
# Nearest to his: their, her, its, the, fealty, s, this, formalization,
# Nearest to often: also, still, sometimes, usually, now, commonly, generally, punished,
# Nearest to state: acm, nia, states, capital, boast, plenum, refugees, fulfills,
# Nearest to i: consubstantiation, ii, they, libyans, you, we, motivating, sindh,
# Nearest to called: mut, impractical, cooled, considered, agadir, used, mace, pickard,
# Nearest to they: there, we, he, it, not, you, who, she,
# Nearest to there: they, it, he, now, usually, often, generally, still,
# Nearest to was: is, had, has, were, became, been, be, americana,
# Nearest to by: was, tou, against, talons, bradbury, were, and, actually,
# Average loss at step 32000: 3.498592
# Average loss at step 34000: 3.492111
# Average loss at step 36000: 3.460112
# Average loss at step 38000: 3.300274
# Average loss at step 40000: 3.429134
# Nearest to about: spr, roughly, koestler, organisational, nominal, certainly, unreleased, fineness,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to at: in, during, over, server, between, basement, on, cccc,
# Nearest to on: upon, in, peas, splintered, dan, godhead, occult, at,
# Nearest to and: or, but, to, doe, in, melee, stump, however,
# Nearest to is: was, has, are, be, does, somme, btr, if,
# Nearest to but: however, and, although, though, while, which, are, it,
# Nearest to his: their, her, its, the, s, fealty, my, parameter,
# Nearest to often: usually, also, sometimes, still, now, commonly, generally, typically,
# Nearest to state: acm, nia, states, boast, capital, government, rod, fulfills,
# Nearest to i: you, they, we, ii, consubstantiation, midday, t, god,
# Nearest to called: considered, used, mut, like, cooled, impractical, named, alive,
# Nearest to they: we, there, he, you, it, i, these, she,
# Nearest to there: they, it, he, now, usually, often, sometimes, she,
# Nearest to was: is, has, had, became, were, be, been, pxe,
# Nearest to by: with, addons, be, ferris, arcades, when, wheatstone, dactyl,
# Average loss at step 42000: 3.435131
# Average loss at step 44000: 3.453898
# Average loss at step 46000: 3.452225
# Average loss at step 48000: 3.359060
# Average loss at step 50000: 3.384921
# Nearest to about: spr, over, roughly, koestler, assistive, rodin, around, livius,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to at: in, during, on, under, cccc, fetish, basement, near,
# Nearest to on: upon, in, splintered, peas, at, into, bitters, finer,
# Nearest to and: or, of, but, including, s, ua, than, serials,
# Nearest to is: was, has, are, does, became, vinny, becomes, contains,
# Nearest to but: however, though, although, while, when, and, there, which,
# Nearest to his: her, their, its, my, the, fealty, him, nearing,
# Nearest to often: usually, sometimes, also, commonly, generally, still, now, typically,
# Nearest to state: states, acm, nia, capital, sulfate, interior, boast, viable,
# Nearest to i: you, we, ii, they, postulating, t, midday, justifying,
# Nearest to called: used, considered, known, named, mut, referred, bubble, guesses,
# Nearest to they: we, he, there, she, you, it, who, these,
# Nearest to there: they, it, he, now, usually, she, still, which,
# Nearest to was: is, has, became, were, had, be, been, borrowing,
# Nearest to by: addons, through, against, while, under, newly, was, with,
# Average loss at step 52000: 3.434502
# Average loss at step 54000: 3.427725
# Average loss at step 56000: 3.437232
# Average loss at step 58000: 3.393655
# Average loss at step 60000: 3.394452
# Nearest to about: spr, over, koestler, nominal, fineness, between, assistive, roughly,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to at: in, near, during, before, under, basement, accretion, methodist,
# Nearest to on: upon, through, in, ipx, deceived, peas, splintered, formulations,
# Nearest to and: or, but, including, serials, than, although, glockenspiel, in,
# Nearest to is: was, are, has, seems, does, although, remains, becomes,
# Nearest to but: however, and, although, see, though, roper, appropriating, endosymbiont,
# Nearest to his: her, their, its, my, dawson, the, nearing, commanders,
# Nearest to often: sometimes, usually, commonly, generally, now, also, still, typically,
# Nearest to state: government, nia, states, interior, acm, fulfills, doctrine, capital,
# Nearest to i: you, we, ii, g, midday, they, postulating, not,
# Nearest to called: used, considered, mut, known, named, referred, spin, boyd,
# Nearest to they: we, there, you, he, she, these, it, who,
# Nearest to there: they, it, now, he, still, this, generally, she,
# Nearest to was: is, had, became, has, were, does, been, when,
# Nearest to by: mapquest, through, with, talons, annan, tou, unreleased, addons,
# Average loss at step 62000: 3.242461
# Average loss at step 64000: 3.256326
# Average loss at step 66000: 3.407061
# Average loss at step 68000: 3.397256
# Average loss at step 70000: 3.359299
# Nearest to about: spr, over, roughly, fineness, snl, around, koestler, rodin,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to at: during, near, in, after, accretion, before, under, finer,
# Nearest to on: upon, in, through, within, deceived, near, circuit, abstracted,
# Nearest to and: or, but, while, which, regarding, including, like, contaminants,
# Nearest to is: was, has, be, are, becomes, seems, does, somme,
# Nearest to but: however, although, see, though, that, and, which, suevi,
# Nearest to his: her, their, its, my, fealty, our, dawson, nearing,
# Nearest to often: sometimes, usually, generally, now, commonly, also, still, frequently,
# Nearest to state: government, states, nia, interior, city, acm, jin, dancing,
# Nearest to i: we, you, ii, g, midday, they, dns, epigrams,
# Nearest to called: used, considered, known, named, referred, mut, submerged, term,
# Nearest to they: we, there, he, you, she, it, who, these,
# Nearest to there: they, it, now, we, still, he, generally, she,
# Nearest to was: is, were, has, had, became, been, when, borrowing,
# Nearest to by: through, pasha, morpheus, talons, strategos, compatibles, while, from,
# Average loss at step 72000: 3.375078
# Average loss at step 74000: 3.349701
# Average loss at step 76000: 3.318133
# Average loss at step 78000: 3.353271
# Average loss at step 80000: 3.379176
# Nearest to about: spr, fineness, approximately, snl, over, roughly, assistive, nominal,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to at: in, during, on, throughout, after, accretion, before, artcyclopedia,
# Nearest to on: upon, in, through, at, finer, octahedron, under, during,
# Nearest to and: or, but, demonym, including, hereford, serials, yeah, while,
# Nearest to is: was, has, are, restatement, becomes, be, gives, seems,
# Nearest to but: however, although, see, though, and, while, he, or,
# Nearest to his: her, their, my, its, our, your, fealty, nearing,
# Nearest to often: sometimes, usually, commonly, generally, now, still, frequently, typically,
# Nearest to state: government, states, city, interior, capital, nia, sulfate, complained,
# Nearest to i: you, we, ii, g, midday, v, particulars, penderecki,
# Nearest to called: used, known, considered, referred, named, submerged, refuting, chosen,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to there: it, they, he, now, she, we, still, often,
# Nearest to was: is, became, were, had, has, been, when, borrowing,
# Nearest to by: when, cyclopentadienyl, through, viking, from, under, compatibles, rationalists,
# Average loss at step 82000: 3.408819
# Average loss at step 84000: 3.414139
# Average loss at step 86000: 3.387996
# Average loss at step 88000: 3.352602
# Average loss at step 90000: 3.364386
# Nearest to about: fineness, assistive, spr, nominal, over, snl, roughly, decrees,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to at: during, near, on, under, in, throughout, accretion, around,
# Nearest to on: upon, under, at, through, around, ipx, lr, americana,
# Nearest to and: or, but, while, including, demonym, wark, serials, of,
# Nearest to is: was, has, are, although, becomes, be, contains, sculptural,
# Nearest to but: however, and, although, while, though, hypothesized, that, see,
# Nearest to his: her, their, its, my, our, your, the, basilisk,
# Nearest to often: sometimes, usually, commonly, generally, now, still, also, frequently,
# Nearest to state: government, city, states, interior, tolerances, nia, sulfate, controlling,
# Nearest to i: we, you, ii, g, they, v, penderecki, midday,
# Nearest to called: used, referred, known, named, considered, chosen, dendritic, refuting,
# Nearest to they: we, there, you, he, she, it, these, brigitte,
# Nearest to there: they, it, he, we, she, still, now, generally,
# Nearest to was: is, had, became, were, has, be, been, styled,
# Nearest to by: while, when, elan, through, with, mattia, tou, under,
# Average loss at step 92000: 3.399158
# Average loss at step 94000: 3.255787
# Average loss at step 96000: 3.359833
# Average loss at step 98000: 3.242764
# Average loss at step 100000: 3.355955
# Nearest to about: spr, roughly, around, nominal, snl, over, pivots, assistive,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to at: during, on, in, near, accretion, finer, under, after,
# Nearest to on: upon, in, through, under, within, at, into, finer,
# Nearest to and: or, but, although, while, however, violet, leadbelly, when,
# Nearest to is: was, has, are, contains, had, be, americana, becomes,
# Nearest to but: however, although, and, though, while, delicately, probably, ahern,
# Nearest to his: her, their, my, its, our, your, the, fealty,
# Nearest to often: sometimes, usually, commonly, generally, typically, now, frequently, still,
# Nearest to state: government, city, states, sulfate, kimball, complained, nia, overheat,
# Nearest to i: you, we, ii, they, v, ornate, g, justifying,
# Nearest to called: used, referred, named, known, considered, cfc, dendritic, submerged,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to there: they, it, he, we, now, still, she, often,
# Nearest to was: is, became, were, had, has, been, styled, irishman,
# Nearest to by: without, mattia, tou, trigonometric, been, arcades, cyclopentadienyl, be,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    col_idx = 0
    for j in range(span):
        if j == span // 2:
            continue
        batch[i, col_idx] = buffer[j]
        col_idx += 1
    labels[i, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1,2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window, ))
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = None
  for i in range(2*skip_window):
    print(train_dataset[:,i].shape)
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
    print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
    emb_x,emb_y = embedding_i.get_shape().as_list()
    if embeds is None:
      embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
    else:
      embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])], 2)
  embeds = tf.reduce_mean(embeds,2,keep_dims=False)
  print(embeds.shape)
  print(train_labels.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embeds,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128,)
# embedding 0 shape: [128, 128]
# (128,)
# embedding 1 shape: [128, 128]
# (128, 128)
# (128, 1)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.067661
# Nearest to two: strathclyde, fortified, muriel, compelling, breisgau, kista, wahhabism, designers,
# Nearest to he: lcds, invite, frustrating, comedies, frantz, rewritten, polarised, parsed,
# Nearest to four: cigar, danorum, logan, fon, capitalisation, aleuts, resumes, hurriedly,
# Nearest to seven: appalachian, tca, hildebrand, maimonides, collegiate, hermaphroditus, micronations, statutes,
# Nearest to only: devotes, cegep, weights, client, jain, fairbanks, equals, bund,
# Nearest to other: oxidative, floresiensis, promiscuity, nen, contender, tolerated, hallmark, hendrick,
# Nearest to many: mebyon, inefficiencies, telling, evaded, palatine, urgency, force, khwarizmi,
# Nearest to so: talmud, stanton, clue, genie, clad, feynman, alcoholics, unlicensed,
# Nearest to most: organelle, denominations, slave, sata, chased, foreign, scorpio, naghten,
# Nearest to also: propriety, demigods, begging, fortification, instance, nutshell, symbolic, attracted,
# Nearest to see: redistricting, equivalent, contribution, supervisory, busch, haman, bravely, ibiblio,
# Nearest to s: otters, angelica, signifier, vulnerabilities, contents, master, auteurs, reciprocate,
# Nearest to world: dismantled, sylia, cliffordadams, slippage, jinn, kmt, males, idiosyncratic,
# Nearest to state: serviced, swordsmiths, oppenheim, golding, watermelon, invariably, watchful, aldrin,
# Nearest to was: reappeared, climbing, reorganized, pmod, biennial, detectors, vow, commando,
# Nearest to were: heir, conclusive, forehead, fournier, ascended, hyperactivity, morgue, residences,
# Average loss at step 2000: 4.039694
# Average loss at step 4000: 3.504728
# Average loss at step 6000: 3.348139
# Average loss at step 8000: 3.195136
# Average loss at step 10000: 3.153237
# Nearest to two: three, eight, four, six, one, five, seven, nine,
# Nearest to he: it, she, they, who, frantz, tractable, lcds, comedies,
# Nearest to four: five, eight, three, six, seven, two, zero, nine,
# Nearest to seven: nine, eight, five, six, four, three, zero, two,
# Nearest to only: denton, preferable, faraway, checkpoints, lok, suspensions, reciprocate, suspicious,
# Nearest to other: nacht, viva, ribozymes, floresiensis, contender, ingenuity, discounted, many,
# Nearest to many: these, some, bun, social, inefficiencies, other, evaded, all,
# Nearest to so: talmud, genie, alcoholics, mee, very, userbase, beg, aridity,
# Nearest to most: slave, sata, chased, cryptozoologists, oup, denominations, vasari, fitness,
# Nearest to also: which, ecd, capuchin, varanus, homophobic, not, sometimes, who,
# Nearest to see: can, busch, formidable, contribution, ibiblio, haman, secam, cystic,
# Nearest to s: lament, signifier, hematite, ma, whose, pied, memories, synchronicity,
# Nearest to world: wynn, sylia, cradle, dismantled, idiosyncratic, deformity, cliffordadams, sorceress,
# Nearest to state: serviced, oppenheim, fragments, germination, saiyan, ticonderoga, variance, superstars,
# Nearest to was: is, has, were, became, had, vanity, davy, be,
# Nearest to were: are, was, have, had, microgravity, is, atrial, lensman,
# Average loss at step 12000: 3.176252
# Average loss at step 14000: 3.132202
# Average loss at step 16000: 3.148922
# Average loss at step 18000: 3.103751
# Average loss at step 20000: 3.000570
# Nearest to two: three, four, six, one, seven, eight, five, drastically,
# Nearest to he: she, it, they, who, islington, there, tractable, contracted,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to only: denton, suspicious, explainable, eridanus, faraway, preferable, industrialised, berle,
# Nearest to other: different, nacht, viva, door, styne, ingenuity, floresiensis, axon,
# Nearest to many: some, these, several, most, such, deplete, mentats, bun,
# Nearest to so: talmud, genie, very, mee, beg, supra, alcoholics, rodan,
# Nearest to most: sata, more, vasari, many, cryptozoologists, slave, fitness, oup,
# Nearest to also: sometimes, often, generally, which, ecd, formerly, homophobic, kasner,
# Nearest to see: busch, can, ibiblio, contribution, cystic, secam, wake, haman,
# Nearest to s: lament, whose, conde, pied, ma, signifier, his, hematite,
# Nearest to world: wynn, cradle, idiosyncratic, sylia, deformity, announcement, dismantled, jinn,
# Nearest to state: serviced, fragments, saiyan, germination, oppenheim, ticonderoga, editorial, carey,
# Nearest to was: is, has, became, were, had, be, mcvie, vanity,
# Nearest to were: are, have, was, microgravity, had, yy, vanity, residences,
# Average loss at step 22000: 3.055956
# Average loss at step 24000: 3.022504
# Average loss at step 26000: 2.990145
# Average loss at step 28000: 3.018421
# Average loss at step 30000: 2.991799
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to he: she, it, they, who, there, never, ruth, tractable,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to only: explainable, denton, industrialised, eridanus, charted, cv, preferable, just,
# Nearest to other: different, various, nacht, many, viva, styne, floresiensis, contender,
# Nearest to many: some, several, these, various, such, most, other, those,
# Nearest to so: talmud, saying, beg, genie, supra, metcalfe, promises, recruited,
# Nearest to most: more, vasari, many, sata, fitness, chased, cryptozoologists, slave,
# Nearest to also: often, still, sometimes, now, generally, formerly, which, homophobic,
# Nearest to see: busch, can, ibiblio, daoism, but, cystic, aztlan, secam,
# Nearest to s: legalisation, conde, pied, lament, discontinuation, realtime, whose, barkley,
# Nearest to world: cradle, idiosyncratic, wynn, sylia, deformity, announcement, males, post,
# Nearest to state: serviced, saiyan, fragments, germination, oppenheim, staley, carey, tricity,
# Nearest to was: is, became, has, had, were, be, been, davy,
# Nearest to were: are, have, was, had, microgravity, vanity, been, yy,
# Average loss at step 32000: 2.836030
# Average loss at step 34000: 2.952028
# Average loss at step 36000: 2.933484
# Average loss at step 38000: 2.937760
# Average loss at step 40000: 2.921164
# Nearest to two: three, six, five, four, seven, eight, one, zero,
# Nearest to he: she, it, they, there, who, islington, never, tractable,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to only: explainable, always, industrialised, just, cv, suspicious, tended, preferable,
# Nearest to other: different, viva, various, styne, nacht, multiple, many, including,
# Nearest to many: some, several, these, most, various, those, all, such,
# Nearest to so: talmud, saying, genie, supra, beg, promises, ergot, recruited,
# Nearest to most: more, many, vasari, sata, less, some, chased, attenuated,
# Nearest to also: often, now, still, sometimes, generally, formerly, actually, which,
# Nearest to see: aztlan, busch, cystic, daoism, ibiblio, mythologie, can, morehouse,
# Nearest to s: conde, discontinuation, legalisation, pied, algal, mariana, xena, fountains,
# Nearest to world: cradle, idiosyncratic, wynn, males, announcement, obadiah, deformity, etymologically,
# Nearest to state: saiyan, serviced, city, fragments, staley, augmentation, germination, carey,
# Nearest to was: is, became, were, had, has, be, been, davy,
# Nearest to were: are, have, was, had, vanity, microgravity, been, be,
# Average loss at step 42000: 2.944148
# Average loss at step 44000: 2.941177
# Average loss at step 46000: 2.908523
# Average loss at step 48000: 2.866199
# Average loss at step 50000: 2.844958
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to he: she, it, they, there, who, we, finally, never,
# Nearest to four: five, three, six, seven, eight, two, nine, zero,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to only: always, just, charted, explainable, industrialised, eridanus, perpetually, spurred,
# Nearest to other: different, various, viva, styne, multiple, flashback, including, nacht,
# Nearest to many: some, several, these, various, most, all, such, few,
# Nearest to so: saying, genie, talmud, supra, argues, beg, metcalfe, too,
# Nearest to most: more, many, less, vasari, some, sata, chased, attenuated,
# Nearest to also: now, often, actually, still, sometimes, generally, never, formerly,
# Nearest to see: aztlan, yakko, daoism, can, mythologie, busch, polytechnical, references,
# Nearest to s: pied, legalisation, fountains, his, lament, disclose, hematite, jets,
# Nearest to world: cradle, idiosyncratic, wynn, obadiah, announcement, deformity, males, wilmut,
# Nearest to state: saiyan, city, serviced, fragments, government, victoria, invention, staley,
# Nearest to was: is, became, were, had, has, been, be, ci,
# Nearest to were: are, have, was, had, microgravity, been, vanity, while,
# Average loss at step 52000: 2.883025
# Average loss at step 54000: 2.864116
# Average loss at step 56000: 2.853875
# Average loss at step 58000: 2.761989
# Average loss at step 60000: 2.822356
# Nearest to two: three, four, six, five, one, eight, seven, zero,
# Nearest to he: she, it, they, there, who, finally, eventually, we,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to seven: five, six, eight, nine, four, zero, three, two,
# Nearest to only: always, just, charted, preferable, centerline, bitmap, kurf, industrialised,
# Nearest to other: different, viva, various, including, others, styne, multiple, flashback,
# Nearest to many: some, several, various, these, most, few, those, all,
# Nearest to so: supra, saying, genie, talmud, too, argues, recruited, metcalfe,
# Nearest to most: more, many, less, vasari, some, sata, use, chased,
# Nearest to also: actually, often, still, now, generally, sometimes, never, usually,
# Nearest to see: aztlan, cystic, references, can, morehouse, but, busch, ills,
# Nearest to s: pied, whose, aonb, legalisation, hematite, isbn, discontinuation, jets,
# Nearest to world: cradle, idiosyncratic, reproach, obadiah, deformity, announcement, wynn, mbeki,
# Nearest to state: saiyan, government, majority, city, fragments, victoria, states, serviced,
# Nearest to was: is, had, became, were, has, be, been, appears,
# Nearest to were: are, have, was, had, microgravity, been, those, be,
# Average loss at step 62000: 2.836378
# Average loss at step 64000: 2.777689
# Average loss at step 66000: 2.770213
# Average loss at step 68000: 2.723345
# Average loss at step 70000: 2.773051
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to he: she, it, they, who, there, eventually, we, lange,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to only: industrialised, just, eridanus, charted, always, bitmap, preferable, unsound,
# Nearest to other: various, different, individual, multiple, many, viva, styne, delineation,
# Nearest to many: some, several, various, most, these, all, those, few,
# Nearest to so: too, supra, saying, genie, argues, ergot, recruited, rastafari,
# Nearest to most: more, many, less, some, vasari, sata, chased, unbounded,
# Nearest to also: now, actually, often, still, never, generally, sometimes, which,
# Nearest to see: references, aztlan, cystic, busch, morehouse, daoism, striping, mythologie,
# Nearest to s: pied, isbn, aonb, discontinuation, his, hematite, legalisation, conde,
# Nearest to world: cradle, reproach, idiosyncratic, obadiah, announcement, tide, mbeki, deformity,
# Nearest to state: saiyan, government, states, city, fragments, victoria, majority, cth,
# Nearest to was: is, became, had, were, has, be, ci, been,
# Nearest to were: are, was, have, had, been, those, microgravity, include,
# Average loss at step 72000: 2.801655
# Average loss at step 74000: 2.655129
# Average loss at step 76000: 2.803934
# Average loss at step 78000: 2.820816
# Average loss at step 80000: 2.786976
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to he: she, it, they, there, who, we, eventually, ultimately,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to only: just, unsound, charted, always, either, industrialised, eridanus, both,
# Nearest to other: various, different, individual, multiple, viva, styne, many, madam,
# Nearest to many: some, several, various, most, few, all, those, these,
# Nearest to so: too, argues, genie, saying, vantaa, supra, rastafari, beg,
# Nearest to most: many, more, less, some, vasari, unbounded, chased, sata,
# Nearest to also: now, often, actually, generally, still, never, sometimes, usually,
# Nearest to see: references, aztlan, busch, but, daoism, morehouse, called, include,
# Nearest to s: whose, pied, isbn, legalisation, lament, disclose, eyre, realtime,
# Nearest to world: cradle, obadiah, idiosyncratic, reproach, offa, mbeki, tide, deformity,
# Nearest to state: saiyan, city, states, government, fragments, victoria, majority, bolsheviks,
# Nearest to was: is, became, were, had, has, be, been, becomes,
# Nearest to were: are, have, was, had, been, microgravity, those, harpercollins,
# Average loss at step 82000: 2.681425
# Average loss at step 84000: 2.772828
# Average loss at step 86000: 2.739732
# Average loss at step 88000: 2.755702
# Average loss at step 90000: 2.742199
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to he: she, it, they, there, who, we, ultimately, eventually,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to seven: six, eight, nine, five, four, zero, three, two,
# Nearest to only: always, just, either, unsound, charted, easily, onshore, centerline,
# Nearest to other: various, different, multiple, individual, viva, many, mahommed, goi,
# Nearest to many: several, some, various, most, few, numerous, all, these,
# Nearest to so: too, argues, genie, saying, vantaa, supra, schoolgirl, rastafari,
# Nearest to most: more, many, less, some, vasari, especially, highly, unbounded,
# Nearest to also: now, often, actually, never, still, generally, rarely, sometimes,
# Nearest to see: references, aztlan, but, list, busch, complements, morehouse, include,
# Nearest to s: whose, isbn, legalisation, pied, disclose, aonb, accompaniments, angered,
# Nearest to world: cradle, reproach, idiosyncratic, country, obadiah, mbeki, tide, offa,
# Nearest to state: saiyan, city, government, majority, victoria, cth, states, fragments,
# Nearest to was: is, became, has, had, becomes, were, be, appears,
# Nearest to were: are, have, had, was, microgravity, been, those, being,
# Average loss at step 92000: 2.689144
# Average loss at step 94000: 2.726996
# Average loss at step 96000: 2.709089
# Average loss at step 98000: 2.386999
# Average loss at step 100000: 2.423256
# Nearest to two: three, five, six, four, seven, eight, nine, zero,
# Nearest to he: she, they, it, there, we, who, ultimately, eventually,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to only: charted, eridanus, just, centerline, always, industrialised, onshore, celts,
# Nearest to other: various, individual, muslim, styne, others, multiple, different, goi,
# Nearest to many: some, several, various, numerous, few, most, these, all,
# Nearest to so: too, argues, genie, saying, vantaa, schoolgirl, thus, very,
# Nearest to most: more, less, many, some, especially, highly, vasari, unbounded,
# Nearest to also: now, actually, never, often, still, sometimes, which, generally,
# Nearest to see: references, external, busch, called, aztlan, include, scavenge, but,
# Nearest to s: whose, pied, american, his, isbn, aonb, wesley, dm,
# Nearest to world: cradle, reproach, idiosyncratic, obadiah, tide, announcement, altay, mbeki,
# Nearest to state: saiyan, states, government, city, majority, mention, cth, national,
# Nearest to was: is, had, became, has, be, were, been, wrote,
# Nearest to were: are, have, was, had, microgravity, include, be, been,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
